# %% [markdown]
# <a href="https://colab.research.google.com/github/Sk3ngi/artificial-intelligence-for-trading/blob/master/tickers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
nasdaq_txt=r'http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NASDAQ&render=download'
nyse_txt=r'http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NYSE&render=download'
six = r'https://www.six-group.com/exchanges/shares/companies/download/issuers_all_en.csv'
lse=r'https://www.londonstockexchange.com/statistics/companies-and-issuers/companies-defined-by-mifir-identifiers-list-on-lse.xlsx'

# %%
# !pip install alpha_vantage
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/21/9c/02/b7cfae63f7119f4089f229ba1a09ce90fabbaf96199c2890be
# Successfully built alpha-vantage
# ...

# %%
from alpha_vantage.timeseries import TimeSeries
def get_pricing(ticker):
  av_api_key='NXGF5T6YWX0SAQHC'
  ts = TimeSeries(key=av_api_key,output_format='pandas', indexing_type='date')
  data, meta_data = ts.get_intraday(ticker)
  return data

# %%
get_pricing('GOOGL')
# Out:
#                        1. open    2. high     3. low   4. close  5. volume
# date
# 2019-06-11 10:45:00  1101.6600  1104.0050  1100.0000  1100.0950    73183.0
# 2019-06-11 11:00:00  1100.0950  1101.6350  1093.6200  1097.2600    64210.0
# 2019-06-11 11:15:00  1097.4100  1097.4100  1094.6600  1095.0900    29866.0
# 2019-06-11 11:30:00  1094.6417  1097.7300  1092.6300  1092.9200    41297.0
# 2019-06-11 11:45:00  1093.0000  1094.0300  1086.0300  1088.8600    73648.0
# 2019-06-11 12:00:00  1088.6300  1090.0900  1086.2700  1088.3400    40815.0
# 2019-06-11 12:15:00  1088.5000  1088.5000  1086.0000  1086.4100    38837.0
# 2019-06-11 12:30:00  1086.0100  1088.1700  1085.7100  1086.4399    34534.0
# 2019-06-11 12:45:00  1086.3400  1089.2100  1086.3400  1087.6450    29100.0
# 2019-06-11 13:00:00  1087.1400  1088.3101  1085.4600  1086.0000    26913.0
# 2019-06-11 13:15:00  1085.8000  1087.8000  1085.4600  1087.8000    21529.0
# ...

# %%
import matplotlib.pyplot as plt
data[['2. high', '3. low', '4. close']].plot()

# %%
pd.read_csv(six,error_bad_lines=False,encoding='latin1',delimiter=';')
#a=requests.get(lse)
#pd.read_excel(lse,header=5)
# Out:
#                                Company  ... Primary listing
# 0                           3M Company  ...           False
# 1                              ABB Ltd  ...            True
# 2                  Abbott Laboratories  ...           False
# 3               Addex Therapeutics Ltd  ...            True
# 4                      Adecco Group AG  ...            True
# 5                Adval Tech Holding AG  ...            True
# 6                    AEVIS VICTORIA SA  ...            True
# 7                           Airesis SA  ...            True
# 8         Airopack Technology Group AG  ...            True
# 9                           Alcon Inc.  ...            True
# 10                  Allreal Holding AG  ...            True
# 11                    Alpine Select AG  ...            True
# 12                    Alpiq Holding AG  ...            True
# 13                     ALSO Holding AG  ...            True
# 14                              ams AG  ...            True
# ...

# %%
pd.read_excel(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-52910139a783> in <module>()
# ----> 1 pd.read_excel(a)
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...
